# %%
#pip install openpyxl
import pandas as pd

# %%
df=pd.read_html('https://www.freeformatter.com/mime-types-list.html')

# %%
df[0]
# Out:
#                                                   Name  \
# 0                                       Andrew Toolkit
# 1                                           Applixware
# 2                              Atom Syndication Format
# 3                             Atom Publishing Protocol
# 4            Atom Publishing Protocol Service Document
# ..                                                 ...
# 686                                           CoolTalk
# 687                                BAS Partitur Format
# 688  YAML Ain't Markup Language / Yet Another Marku...
# 689                                   Apple Disk Image
# 690                                GPS eXchange Format
#
#     MIME Type / Internet Media Type File Extension  \
# 0          application/andrew-inset            NaN
# 1            application/applixware            .aw
# 2              application/atom+xml    .atom, .xml
# 3           application/atomcat+xml       .atomcat
# ...

# %%
df[0].to_csv("test.csv")

# %%
df[0].to_excel("test.xlsx")
